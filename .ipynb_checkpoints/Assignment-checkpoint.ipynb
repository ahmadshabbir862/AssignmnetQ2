# %%
import numpy as np   
import pandas as pd

# %% [markdown]
# # PART 1

# %%
states0 = pd.read_csv('states0.csv', index_col=0)
states1 = pd.read_csv('states1.csv', index_col=0)
states2 = pd.read_csv('states2.csv', index_col=0)
states3 = pd.read_csv('states3.csv', index_col=0)
states4 = pd.read_csv('states4.csv', index_col=0)
states5 = pd.read_csv('states5.csv', index_col=0)
states6 = pd.read_csv('states6.csv', index_col=0)
states7 = pd.read_csv('states7.csv', index_col=0)
states8 = pd.read_csv('states8.csv', index_col=0)
states9 = pd.read_csv('states9.csv', index_col=0)

# %%
display(states3)
display(states5)
display(states9)
# Out:
#        State  TotalPop             Hispanic                White  \
# 0       Iowa   3093526    5.30364520048603%   87.71968408262464%
# 1     Kansas   2892987  11.644342105263148%   75.95828947368425%
# 2   Kentucky   4397353   3.222993688007212%    85.2307484220019%
# 3  Louisiana   4625253   4.866489361702128%  54.978546099290796%
# 4      Maine   1329100  1.4319088319088318%   93.70740740740736%
# 5   Maryland   5930538    8.47249820014399%     52.679049676026%
#
#                  Black                Native                Asian  \
# 0  3.2569866342648868%   0.2897934386391251%   1.699392466585662%
# 1     6.5678947368421%   0.7339473684210529%   2.331052631578946%
# 2   8.272317403065832%   0.1666366095581602%  1.1298467087466182%
# 3   36.32624113475175%  0.48430851063829816%   1.669060283687941%
# 4  1.1344729344729356%   0.7883190883190888%  0.9658119658119669%
# 5    30.6777537796976%  0.20309575233981278%   5.325413966882652%
#
#                  Pacific               Income          GenderPop
# 0  0.055164034021871235%   $53017.75304136253  1534595M_1558931F
# 1                    NaN  $53885.612648221344  1439862M_1453125F
# 2  0.046438232642019836%   $45285.80253623189  2164208M_2233145F
# 3  0.039184397163120555%   $44957.99376114082  2261156M_2364097F
# 4   0.01566951566951567%   $49181.97435897436    650081M_679019F
# 5   0.03628509719222463%   $78765.40072463769         2872643M_F
#            State  TotalPop             Hispanic                White  \
# 0       Missouri   6045448   4.037247838616718%     77.508069164265%
# 1        Montana   1014699  3.2688888888888896%   86.41555555555554%
# 2       Nebraska   1869365   9.203759398496235%   81.13947368421056%
# 3         Nevada   2798636  27.100883652430046%   53.23932253313698%
# 4  New Hampshire   1324201  3.3219178082191796%   91.31917808219184%
# 5     New Jersey   8904413   18.74950049950049%  56.488761238761285%
#
#                  Black                Native                Asian  \
# 0  14.122118155619594%  0.36332853025936646%  1.6244956772334296%
# 1  0.4292592592592591%   7.0607407407407425%  0.5703703703703705%
# 2   4.956203007518794%   0.8644736842105263%  1.8590225563909788%
# 3   7.739617083946994%   1.0871870397643593%   7.095729013254786%
# 4  1.2277397260273974%  0.14280821917808229%   2.191438356164382%
# 5  14.387862137862117%  0.11533466533466513%   8.159990009990018%
#
#                  Pacific               Income          GenderPop
# 0   0.10165706051873193%   $49763.98772563177  2964003M_3081445F
# 1   0.07222222222222222%  $47645.682835820895          510163M_F
# 2   0.05714285714285715%  $55916.469696969696    929606M_939759F
# 3    0.5745213549337267%  $55526.525073746314  1407735M_1390901F
# 4  0.016095890410958904%    $68728.8595890411    653484M_670717F
# 5  0.031318681318681325%   $76581.08341708542  4343027M_4561386F
#            State  TotalPop             Hispanic                White  \
# 0           Utah   2903379  13.468376068376063%   79.40683760683764%
# 1        Vermont    626604  1.6092896174863391%   93.98306010928961%
# 2       Virginia   8256630     8.0110164981373%  63.271048430015945%
# 3     Washington   6985464  11.140968858131506%   72.03840830449816%
# 4  West Virginia   1851420   1.290909090909089%   92.17623966942146%
# 5      Wisconsin   5742117   6.683333333333334%   79.86400862068966%
#
#                  Black                Native                Asian  \
# 0  1.0179487179487194%   1.0813675213675222%   2.196068376068376%
# 1  0.9808743169398909%    0.301639344262295%  1.2387978142076501%
# 2   20.17599787120807%  0.21245343267695582%   5.455242150079845%
# 3   3.384429065743947%   1.4107266435986163%   7.022006920415224%
# 4  3.6628099173553723%  0.15268595041322316%  0.6824380165289253%
# 5   8.195186781609202%   0.9536637931034483%   2.404238505747124%
#
#                  Pacific               Income          GenderPop
# 0    0.8259829059829059%   $63488.91780821918  1459229M_1444150F
# 1   0.03060109289617486%   $55602.96721311475    308573M_318031F
# 2   0.06471527408195847%   $72866.01341201717  4060948M_4195682F
# 3     0.609896193771627%   $64493.76768377254  3487725M_3497739F
# 4   0.02644628099173554%   $41437.11157024794    913631M_937789F
# 5  0.020833333333333332%  $53898.889208633096  2851385M_2890732F

# %%
states = [states0,states1,states2,states3,states4,states5,states6,states7,states8,states9]

# %%
us_cences=pd.concat(states, ignore_index=True)

# %%
us_cences.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_cences.dtypes
# Out:
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %% [markdown]
# There are all columns are objects. These dtypes are not for making histogram.

# %%
us_cences.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# 0  0.03435374149659865%  $43296.35860306644    2341093M_2489527F
# 1   1.0586826347305378%  $70354.74390243902      384160M_349215F
# 2  0.16763157894736833%  $54207.82095490716    3299088M_3342840F
# 3  0.14686131386861315%  $41935.63396778917    1451913M_1506295F
# 4  0.35141038442336353%  $67264.78230266465  19087135M_19334329F

# %% [markdown]
# ### First we convert income dtype into integer.

# %%
us_cences[['Income']].head()
# Out:
#                Income
# 0  $43296.35860306644
# 1  $70354.74390243902
# 2  $54207.82095490716
# 3  $41935.63396778917
# 4  $67264.78230266465

# %% [markdown]
# ## Cleaning of Income

# %%
us_cences['Income'] = us_cences['Income'].replace({'\$': '', ',': ''}, regex=True)
us_cences['Income'] = pd.to_numeric(us_cences['Income'])
us_cences['Income'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Cleaning of Male and Female Population

# %%
us_cences[['GenderPop']].head()
# Out:
#              GenderPop
# 0    2341093M_2489527F
# 1      384160M_349215F
# 2    3299088M_3342840F
# 3    1451913M_1506295F
# 4  19087135M_19334329F

# %%
new = us_cences['GenderPop'].str.split('_', n = 1, expand = True)
us_cences['MalePop']= new[0]
us_cences['FemalePop']= new[1]
us_cences.drop(columns =['GenderPop'], inplace = True)

# %% [markdown]
# ### Now we have two Population Columns

# %%
us_cences.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'MalePop', 'FemalePop'],
#       dtype='object')

# %%
us_cences[['State','MalePop','FemalePop']].head()
# Out:
#         State    MalePop  FemalePop
# 0     Alabama   2341093M   2489527F
# 1      Alaska    384160M    349215F
# 2     Arizona   3299088M   3342840F
# 3    Arkansas   1451913M   1506295F
# 4  California  19087135M  19334329F

# %% [markdown]
# ### Removing M & F

# %%
us_cences['MalePop']= us_cences['MalePop'].replace({'\D':''}, regex=True)
us_cences['FemalePop']= us_cences['FemalePop'].replace({'\D':'', r'^\s*$': np.nan}, regex=True)
us_cences['MalePop']= pd.to_numeric(us_cences['MalePop'])
us_cences['FemalePop']= pd.to_numeric(us_cences['FemalePop'])

# %%
import matplotlib.pyplot as plt

# %%
ax1 = us_cences.plot.scatter(x='FemalePop', y='Income', c='DarkBlue')
plt.show()

# %% [markdown]
# Some FemalePop Rows have NaN values

# %%
us_cences[us_cences['FemalePop'].isna()]
# Out:
#        State  TotalPop             Hispanic               White  \
# 23  Maryland   5930538    8.47249820014399%    52.679049676026%
# 24  Maryland   5930538    8.47249820014399%    52.679049676026%
# 31   Montana   1014699  3.2688888888888896%  86.41555555555554%
#
#                   Black                Native                Asian  \
# 23    30.6777537796976%  0.20309575233981278%   5.325413966882652%
# 24    30.6777537796976%  0.20309575233981278%   5.325413966882652%
# 31  0.4292592592592591%   7.0607407407407425%  0.5703703703703705%
#
#                  Pacific        Income  MalePop  FemalePop
# 23  0.03628509719222463%  78765.400725  2872643        NaN
# 24  0.03628509719222463%  78765.400725  2872643        NaN
# 31  0.07222222222222222%  47645.682836   510163        NaN

# %%
us_cences['FemalePop']= us_cences['FemalePop'].fillna(us_cences['TotalPop']-us_cences['MalePop'])

# %%
us_cences[['State','Income','FemalePop']]
# Out:
#                    State        Income   FemalePop
# 0                Alabama  43296.358603   2489527.0
# 1                 Alaska  70354.743902    349215.0
# 2                Arizona  54207.820955   3342840.0
# 3               Arkansas  41935.633968   1506295.0
# 4             California  67264.782303  19334329.0
# 5               Colorado  64657.801787   2630239.0
# 6               Colorado  64657.801787   2630239.0
# 7            Connecticut  76146.560588   1841615.0
# 8               Delaware  61827.976636    478041.0
# 9   District of Columbia  75466.363636    340810.0
# 10               Florida  50690.194987  10045763.0
# 11               Georgia  50811.082051   5123362.0
# 12               Georgia  50811.082051   5123362.0
# 13                Hawaii  73264.426282    696428.0
# 14                 Idaho  48017.315436    806083.0
# 15              Illinois  59587.048875   6556862.0
# 16               Indiana  48616.227848   3333382.0
# 17                  Iowa  53017.753041   1558931.0
# 18                  Iowa  53017.753041   1558931.0
# 19                Kansas  53885.612648   1453125.0
# 20              Kentucky  45285.802536   2233145.0
# 21             Louisiana  44957.993761   2364097.0
# 22                 Maine  49181.974359    679019.0
# 23              Maryland  78765.400725   3057895.0
# 24              Maryland  78765.400725   3057895.0
# 25         Massachusetts  72838.936726   3455936.0
# 26              Michigan  51201.830037   5038598.0
# 27             Minnesota  62820.833959   2727005.0
# 28           Mississippi  38909.919207   1536358.0
# 29              Missouri  49763.987726   3081445.0
# 30              Missouri  49763.987726   3081445.0
# 31               Montana  47645.682836    504536.0
# 32              Nebraska  55916.469697    939759.0
# 33                Nevada  55526.525074   1390901.0
# 34         New Hampshire  68728.859589    670717.0
# 35            New Jersey  76581.083417   4561386.0
# 36            New Jersey  76581.083417   4561386.0
# 37            New Mexico  47329.967871   1051703.0
# 38              New York  64290.749113  10131373.0
# 39        North Carolina  49937.464137   5049925.0
# 40          North Dakota  58188.112195    353677.0
# 41                  Ohio  49655.248466   5913084.0
# 42                  Ohio  49655.248466   5913084.0
# 43              Oklahoma  48100.854267   1942789.0
# 44                Oregon  54271.901818   1990780.0
# 45          Pennsylvania  56170.464510   6534215.0
# 46           Puerto Rico  20720.538286   1869213.0
# 47          Rhode Island  59125.270833    543273.0
# 48          Rhode Island  59125.270833    543273.0
# 49        South Carolina  46296.807763   2455167.0
# 50          South Dakota  51805.405405    419713.0
# 51             Tennessee  47328.083617   3331859.0
# 52                 Texas  55874.522601  13367298.0
# 53                  Utah  63488.917808   1444150.0
# 54                  Utah  63488.917808   1444150.0
# 55               Vermont  55602.967213    318031.0
# 56              Virginia  72866.013412   4195682.0
# 57            Washington  64493.767684   3497739.0
# 58         West Virginia  41437.111570    937789.0
# 59             Wisconsin  53898.889209   2890732.0

# %%
ax1 = us_cences.plot.scatter(x='FemalePop', y='Income', c='DarkBlue')
plt.show()

# %%
us_cences.duplicated(keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29     True
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53     True
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
us_cences=us_cences.drop_duplicates(subset=['State'])

# %%
scatterplot = us_cences.plot.scatter(x='FemalePop', y='Income', c='Darkblue')

# %% [markdown]
# # PART 2

# %% [markdown]
# ## Reading csv

# %%
inventory = pd.read_csv("inventory.csv")
inventory.columns
# Out:
# Index(['location', 'product_type', 'product_description', 'quantity', 'price'], dtype='object')

# %%
staten_island = inventory.head(10)

# %%
product_request = staten_island[['product_description']]

# %%
inventory[['location']]
# Out:
#          location
# 0   Staten Island
# 1   Staten Island
# 2   Staten Island
# 3   Staten Island
# 4   Staten Island
# 5   Staten Island
# 6   Staten Island
# 7   Staten Island
# 8   Staten Island
# 9   Staten Island
# 10       Brooklyn
# 11       Brooklyn
# 12       Brooklyn
# 13       Brooklyn
# 14       Brooklyn
# 15       Brooklyn
# 16       Brooklyn
# 17       Brooklyn
# 18       Brooklyn
# 19       Brooklyn
# 20         Queens
# 21         Queens
# 22         Queens
# 23         Queens
# 24         Queens
# 25         Queens
# 26         Queens
# 27         Queens
# 28         Queens

# %%
brooklyn = inventory[10:20]

# %%
seed_request = brooklyn[['product_type']]

# %%
inventory['in_stock'] = np.where(inventory['quantity']>0, True, False)
inventory.head()
# Out:
#         location  product_type product_description  quantity  price  in_stock
# 0  Staten Island         seeds               daisy         4   6.99      True
# 1  Staten Island         seeds          calla lily        46  19.99      True
# 2  Staten Island         seeds              tomato        85  13.99      True
# 3  Staten Island  garden tools                rake         4  13.99      True
# 4  Staten Island  garden tools         wheelbarrow         0  89.99     False

# %%
inventory['total_value'] = inventory['quantity']*inventory['price']
inventory.head()
# Out:
#         location  product_type product_description  quantity  price  in_stock  \
# 0  Staten Island         seeds               daisy         4   6.99      True
# 1  Staten Island         seeds          calla lily        46  19.99      True
# 2  Staten Island         seeds              tomato        85  13.99      True
# 3  Staten Island  garden tools                rake         4  13.99      True
# 4  Staten Island  garden tools         wheelbarrow         0  89.99     False
#
#    total_value
# 0        27.96
# 1       919.54
# 2      1189.15
# 3        55.96
# 4         0.00

# %%
combine_lambda = lambda row: \
    '{} - {}'.format(row.product_type, row.product_description)

# %%
inventory['full_description'] = combine_lambda
inventory.head()
# Out:
#         location  product_type product_description  quantity  price  in_stock  \
# 0  Staten Island         seeds               daisy         4   6.99      True
# 1  Staten Island         seeds          calla lily        46  19.99      True
# 2  Staten Island         seeds              tomato        85  13.99      True
# 3  Staten Island  garden tools                rake         4  13.99      True
# 4  Staten Island  garden tools         wheelbarrow         0  89.99     False
#
#    total_value                   full_description
# 0        27.96  <function <lambda> at 0x03C4E7C8>
# 1       919.54  <function <lambda> at 0x03C4E7C8>
# 2      1189.15  <function <lambda> at 0x03C4E7C8>
# 3        55.96  <function <lambda> at 0x03C4E7C8>
# 4         0.00  <function <lambda> at 0x03C4E7C8>
